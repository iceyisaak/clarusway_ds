# %% [markdown]
# <a href="https://ondiande.com/contact/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="ONDIA Contact" width="110" height="200" title="This notebook is licensed by ONDIA. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <hr>
#
# <a href="https://lms.clarusway.com/mod/lesson/view.php?id=2463&pageid=4531&startlastseen=no"><img align="center" src="https://i.ibb.co/6Z5pQxD/lmss.png" alt="Open in Clarusway LMS" width="70" height="200" title="Open Clarusway Learning Management Sytem"></a>
#
# <a href="https://github.com/clarusway/DS-DE-0322-Students/blob/main/3-%20Classes%26Labs/2-DAwPY/DAwPy_S01_(Numpy_Arrays).ipynb"><img align="left" src="https://i.ibb.co/n3HWyQX/github-logo.png" alt="Open in Clarusway GitHub" width="90" height="150" title="Open and Execute in Clarusway GitHub Repository"></a>
#
# <a href="https://nbviewer.org/github/4dsolutions/clarusway_data_analysis/blob/main/DAwPy_S1_%28Numpy_Arrays%29/DAwPy_S1_%28Numpy_Arrays%29.ipynb"><img align="right" src="https://i.ibb.co/48wtV8c/nbviewer-badge.png" alt="Open in nbviewer" width="100" height="100" title="Open and Execute in nbviewer"></a><br/>
#
# <hr>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/XS0bxSH/best-bootcamps.png" width="300" height="200" class="img-fluid" alt="Best Bootcamp Batches"></p>
#
# <br>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="500" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <br>
#
# <img src=https://i.ibb.co/HgnTPh9/stats.png width="500" height="200">
#
#
# ![Image_Assignment](https://i.ibb.co/cY9HhF7/bnote-assignment.gif)
#
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Assignment 02 (Confidence Interval & Hypothesis)</p>

# %% [markdown]
#  ### <span style="color:#49519E">1. Import NumPy, SciPy, Pandas, Matplolib, and Seaborn Libraries.<span>

# %%
import numpy as np
from scipy import stats
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Confidence Interval</p>

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-1:</p>
#
# + What is the normal body temperature for healthy humans? A random sample of
# 130 healthy human body temperatures provided by Allen Shoemaker yielded 98.25 degrees and standard deviation 0.73 degrees.
#
# - Give a 99% confidence interval for the average body temperature of healthy people.

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First write the given variables:</p>

# %%
n = 130
sd = 0.73
sample_mean = 98.25
ci = 0.99

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Second calculate te standard error of te mean (SEM):</p>

# %%
sem = sd/np.sqrt(n)

sem
# Out:
# 0.06402523540941313

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Third calculate the interval at the given confidence level:</p>

# %%
critical_value = stats.t.ppf(0.995, df=n-1)

critical_value
# Out:
# 2.61447867993781

# %%
# margin_of_error = critical_value * (sd/n**0.5)
margin_of_error = critical_value * sem

margin_of_error
# Out:
# 0.16739261295591

# %%
upper_limit = sample_mean + margin_of_error

upper_limit
# Out:
# 98.41739261295591

# %%
lower_limit = sample_mean - margin_of_error

lower_limit
# Out:
# 98.08260738704409

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Last make a decision:</p>

# %%
print(f'With 99% confidence level, we can conclude that, the normal body temp is between {lower_limit:.2f}°F and {upper_limit:.2f}°F.')
# Out:
# With 99% confidence level, we can conclude that, the normal body temp is between 98.08°F and 98.42°F.

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-2:</p>
#
# + The administrators for a hospital wished to estimate the average number of days required for inpatient treatment of patients between the ages of 25 and 34. A random sample of 500 hospital patients between these ages produced a mean and standard deviation equal to 5.4 and 3.1 days, respectively.
#
#
# + Construct a 95% confidence interval for the mean length of stay for the population of patients from which the sample was drawn.

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First write the given variables:</p>

# %%
n = 500
x_bar = 5.4
sd = 3.1
ci = 0.95

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Second calculate te standard error of te mean (SEM):</p>

# %%
sem = sd/np.sqrt(n)

sem
# Out:
# 0.13863621460498696

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Third calculate the interval at the given confidence level:</p>

# %%
ci_z = stats.norm.interval(ci, loc=x_bar, scale=sem)

ci_z
# Out:
# (5.12827801242126, 5.67172198757874)

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Last make a decision:</p>

# %%
print(f'With 95% confidence level, we can conclude that, the length of stay is between {ci_z[0]:.2f} days and {ci_z[1]:.2f} days.')
# Out:
# With 95% confidence level, we can conclude that, the length of stay is between 5.13 days and 5.67 days.

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Hypothesis Testing</p>

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-3:</p>
#
#   - The hourly wages in a particular industry are normally distributed with mean $13.20 and
# standard deviation $2.50. A company in this industry employs 40 workers, paying them an average of $12.20 per hour.
# Can this company be accused of paying substandard wages? Use an α = .01 level test. (Wackerly, Ex.10.18)
#
#
#   - CHECK: statistic: -2.5298221281347035, pvalue= 0.005706018193000826

# %% [markdown]
# ## <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#E9335A; font-size:150%; text-align:left; border-radius:10px 10px;"> REMINDER:</p>
#
# <img src=https://i.ibb.co/G0vg8c2/significance-test-steps.png width="400" height="200">

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First write the given variables:</p>

# %%
mu = 13.20
sd = 2.50
n = 40
x_bar = 12.20
alpha = 0.01
# p_value = 0.005706018193000826

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">1. Stating Null (H0) & Alternative (Ha) Hypotheses:</p>

# %% [raw]
# H0: mu => 13.20
#
# Ha: mu < 13.20

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">2. Calculating Test Statistics:</p>

# %%
t = (x_bar - mu)/(sd * np.sqrt(n))

t
# Out:
# -0.06324555320336758

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">3. Calculaing P-Value:</p>

# %%
p_value = stats.t.cdf(t, df=n-1)

p_value
# Out:
# 0.4749470100516283

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">4. Making a Decision:</p>

# %% [markdown]
# <img src=https://i.ibb.co/NCLKcFs/p-value-reject-area.png width="400" height="200">

# %%
if p_value < alpha:
    print('At {} level of significance, we can reject H0.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject H0.'.format(alpha))
# Out:
# At 0.01 level of significance, we fail to reject H0.

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-4:</p>
#
# + Shear strength measurements derived from unconfined compression tests for two types of soils gave the results shown in the following document (measurements in tons per square foot). Do the soils appear to differ with respect to average shear strength, at the 1% significance level?
#
#
# + Results for two type of soils
#
#
# + CHECK: statistic: 5.1681473319343345, pvalue= 2.593228732352821e-06

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First Read, Assign Dataset to a DataFrame, and Prepare it for Analysis:</p>

# %%
df0 = pd.read_csv("soil.csv")
df0
# Out:
#     Soil1  Soil2
# 0   1.442  1.364
# 1   1.943  1.878
# 2   1.110  1.337
# 3   1.912  1.828
# 4   1.553  1.371
# 5   1.641  1.428
# 6   1.499  1.119
# 7   1.347  1.373
# 8   1.685  1.589
# 9   1.578  1.714
# 10  1.866  1.260
# 11  1.653  1.492
# 12  1.665  1.395
# 13  1.640  1.778
# 14  1.976  1.611
# 15  1.754  1.202
# 16  1.589  1.542
# 17  1.976  1.094
# 18  1.863  1.557
# 19  1.932  1.053
# 20  1.570  1.183
# 21  1.613  1.367
# 22  2.054  1.144
# 23  1.550  1.151
# 24  1.714  1.561
# 25  1.896  1.192
# 26  1.737  1.489
# 27  1.740  1.379
# 28  1.708  1.501
# 29  1.548  1.277
# 30    NaN  1.593
# 31    NaN  1.172
# 32    NaN  1.510
# 33    NaN  1.740
# 34    NaN  1.355

# %%
df = df0.dropna(axis = 0)

df
# Out:
#     Soil1  Soil2
# 0   1.442  1.364
# 1   1.943  1.878
# 2   1.110  1.337
# 3   1.912  1.828
# 4   1.553  1.371
# 5   1.641  1.428
# 6   1.499  1.119
# 7   1.347  1.373
# 8   1.685  1.589
# 9   1.578  1.714
# 10  1.866  1.260
# 11  1.653  1.492
# 12  1.665  1.395
# 13  1.640  1.778
# 14  1.976  1.611
# 15  1.754  1.202
# 16  1.589  1.542
# 17  1.976  1.094
# 18  1.863  1.557
# 19  1.932  1.053
# 20  1.570  1.183
# 21  1.613  1.367
# 22  2.054  1.144
# 23  1.550  1.151
# 24  1.714  1.561
# 25  1.896  1.192
# 26  1.737  1.489
# 27  1.740  1.379
# 28  1.708  1.501
# 29  1.548  1.277

# %%
soil1 = df0["Soil1"].dropna(axis=0)
soil1
# Out:
# 0     1.442
# 1     1.943
# 2     1.110
# 3     1.912
# 4     1.553
# 5     1.641
# 6     1.499
# 7     1.347
# 8     1.685
# 9     1.578
# 10    1.866
# 11    1.653
# 12    1.665
# 13    1.640
# 14    1.976
# 15    1.754
# 16    1.589
# 17    1.976
# 18    1.863
# 19    1.932
# 20    1.570
# 21    1.613
# 22    2.054
# 23    1.550
# 24    1.714
# 25    1.896
# 26    1.737
# 27    1.740
# 28    1.708
# 29    1.548
# Name: Soil1, dtype: float64

# %%
soil2 = df0["Soil2"]
soil2
# Out:
# 0     1.364
# 1     1.878
# 2     1.337
# 3     1.828
# 4     1.371
# 5     1.428
# 6     1.119
# 7     1.373
# 8     1.589
# 9     1.714
# 10    1.260
# 11    1.492
# 12    1.395
# 13    1.778
# 14    1.611
# 15    1.202
# 16    1.542
# 17    1.094
# 18    1.557
# 19    1.053
# 20    1.183
# 21    1.367
# 22    1.144
# 23    1.151
# 24    1.561
# 25    1.192
# 26    1.489
# 27    1.379
# 28    1.501
# 29    1.277
# 30    1.593
# 31    1.172
# 32    1.510
# 33    1.740
# 34    1.355
# Name: Soil2, dtype: float64

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">1. Stating Null (H0) & Alternative (Ha) Hypotheses:</p>

# %% [raw]
# H0: mu_Soil1 == mu_Soil2
#
# Ha: mu_Soil1 != mu_Soil2

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">2. Calculating Test Statistics:</p>

# %%
soil1.describe()
# Out:
# count    30.000000
# mean      1.691800
# std       0.206903
# min       1.110000
# 25%       1.572000
# 50%       1.675000
# 75%       1.865250
# max       2.054000
# Name: Soil1, dtype: float64

# %%
soil2.describe()
# Out:
# count    35.000000
# mean      1.417114
# std       0.219184
# min       1.053000
# 25%       1.231000
# 50%       1.379000
# 75%       1.559000
# max       1.878000
# Name: Soil2, dtype: float64

# %%
indTest = stats.ttest_ind(soil1, soil2, equal_var=True)
indTest
# Out:
# TtestResult(statistic=5.1681473319343345, pvalue=2.593228732352821e-06, df=63.0)

# %%
test_statistic = indTest.statistic
test_statistic
# Out:
# 5.1681473319343345

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">3. Calculaing P-Value:</p>

# %%
p_value = indTest.pvalue
p_value
# Out:
# 2.593228732352821e-06

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">4. Making a Decision:</p>

# %% [markdown]
# <img src=https://i.ibb.co/NCLKcFs/p-value-reject-area.png width="400" height="200">

# %%
alpha = 0.01

if indTest.pvalue < alpha:
    print("Reject H0. At the α=0.01, we have sufficient evidence to indicate that Soil1 differs from Soil2.")
else:
    print("Fail to reject H0.")
# Out:
# Reject H0. At the α=0.01, we have sufficient evidence to indicate that Soil1 differs from Soil2.

# %% [markdown]
# ## <p style="background-color:#58B8E4; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:left; border-radius:10px 10px;"> EXERCISE-5:</p>
#
# + The following dataset is based on data provided by the World Bank
# (https://datacatalog.worldbank.org/dataset/education-statistics). World Bank Edstats.  2015 PISA Test Dataset
#
#
# + Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent
# group (AS, EU, AF, NA, SA, OC).
#
#
# + Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS)
# countries (assume normality and equal variances). Draw side-by-side box plots.
#
#
# + CHECK: statistic=0.870055317967983, pvalue=0.38826888111307345

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">First Explore the Dataset:</p>
#
# Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC).
#
# Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots.

# %%
PISA_Test = pd.read_csv('2015 PISA Test.csv')

PISA_Test
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 1           ARE             AS               90.500000  427.4827  433.5423
# 2           ARG             SA               68.043064  409.0333  425.3031
# 3           AUS             OC               84.560519  493.8962  502.9006
# 4           AUT             EU               83.940142  496.7423  484.8656
# ..          ...            ...                     ...       ...       ...
# 65          TUN             AF               48.519836  366.8180  361.0555
# 66          TUR             EU               53.744979  420.4540  428.3351
# 67          URY             SA               64.600000  417.9919  436.5721
# 68          USA            NaN               74.554202  469.6285  496.9351
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 0   427.2250
# 1   436.7311
# 2   432.2262
# 3   509.9939
# 4   495.0375
# ..       ...
# 65  386.4034
# 66  425.4895
# 67  435.3630
# 68  496.2424
# 69  524.6445
#
# [70 rows x 6 columns]

# %%
PISA_Test['Continent_Code'].value_counts(dropna=False)
# Out:
# Continent_Code
# EU     37
# AS     17
# SA      7
# NaN     5
# OC      2
# AF      2
# Name: count, dtype: int64

# %%
PISA_Test["Continent_Code"].fillna("NA", inplace=True)
PISA_Test['Continent_Code'].value_counts(dropna=False)
# Out:
# Continent_Code
# EU    37
# AS    17
# SA     7
# NA     5
# OC     2
# AF     2
# Name: count, dtype: int64

# %%
PISA_Test.describe()
# Out:
#        internet_users_per_100        Math     Reading     Science
# count               70.000000   70.000000   70.000000   70.000000
# mean                71.973099  460.971557  460.997291  465.439093
# std                 16.390632   53.327205   49.502679   48.397254
# min                 21.976068  327.702000  346.549000  331.638800
# 25%                 60.899020  417.416075  426.948625  425.923375
# 50%                 72.999350  477.607150  480.199850  475.400050
# 75%                 85.026763  500.482925  499.687475  502.431250
# max                 98.200000  564.189700  535.100200  555.574700

# %%
AS = PISA_Test[PISA_Test['Continent_Code'] == 'AS']
AS
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 1           ARE             AS               90.500000  427.4827  433.5423
# 11          CHN             AS               50.300000  531.2961  493.9412
# 25          GEO             AS               47.569760  403.8332  401.2881
# 27          HKG             AS               84.948353  547.9310  526.6753
# 30          IDN             AS               21.976068  386.1096  397.2595
# 33          ISR             AS               77.352090  469.6695  478.9606
# 35          JOR             AS               60.114383  380.2590  408.1022
# 36          JPN             AS               91.058028  532.4399  515.9585
# 37          KAZ             AS               72.900000  459.8160  427.1410
# 38          KOR             AS               89.648631  524.1062  517.4367
# 39          LBN             AS               74.000000  396.2497  346.5490
# 43          MAC             AS               77.600132  543.8078  508.6905
# 49          MYS             AS               71.064068  446.1098  430.5782
# 56          QAT             AS               92.884826  402.4007  401.8874
# 59          SGP             AS               79.012957  564.1897  535.1002
# 63          THA             AS               39.316127  415.4638  409.1301
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 1   436.7311
# 11  517.7793
# 25  411.1315
# 27  523.2774
# 30  403.0997
# 33  466.5528
# 35  408.6691
# 36  538.3948
# 37  456.4836
# 38  515.8099
# 39  386.4854
# 43  528.5496
# 49  442.9475
# 56  417.6112
# 59  555.5747
# 63  421.3373
# 69  524.6445

# %%
EU = PISA_Test[PISA_Test['Continent_Code'] == 'EU']
EU
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 4           AUT             EU               83.940142  496.7423  484.8656
# 5           BEL             EU               85.052900  506.9844  498.5242
# 6           BGR             EU               56.656300  441.1899  431.7175
# 9           CHE             EU               87.479056  521.2506  492.1982
# 14          CYP             EU               71.715900  437.1443  442.8443
# 15          CZE             EU               75.668839  492.3254  487.2501
# 16          DEU             EU               87.589800  505.9713  509.1041
# 17          DNK             EU               96.330500  511.0876  499.8146
# 20          ESP             EU               78.689600  485.8432  495.5764
# 21          EST             EU               88.411812  519.5291  519.1429
# 22          FIN             EU               86.422133  511.0769  526.4247
# 23          FRA             EU               84.694500  492.9204  499.3061
# 24          GBR             EU               92.000300  492.4785  497.9719
# 26          GRC             EU               66.835000  453.6299  467.0395
# 28          HRV             EU               69.803100  464.0401  486.8632
# 29          HUN             EU               72.834700  476.8309  469.5233
# 31          IRL             EU               80.122400  503.7220  520.8148
# 32          ISL             EU               98.200000  488.0332  481.5255
# 34          ITA             EU               58.141735  489.7287  484.7580
# 40          LTU             EU               71.378000  478.3834  472.4066
# 41          LUX             EU               97.334100  485.7706  481.4391
# 42          LVA             EU               79.200600  482.3051  487.7581
# 44          MDA             EU               63.306625  419.6635  416.2293
# 46          MKD             EU               70.380200  371.3114  351.7415
# 47          MLT             EU               76.184000  478.6448  446.6661
# 48          MNE             EU               68.119581  417.9341  426.8845
# 50          NLD             EU               91.724138  512.2528  502.9591
# 51          NOR             EU               96.810300  501.7298  513.1912
# 54          POL             EU               67.997000  504.4693  505.6971
# 55          PRT             EU               68.632900  491.6270  498.1289
# 57          ROU             EU               55.763200  443.9543  433.6166
# 58          RUS             EU               73.410000  494.0600  494.6278
# 60          SVK             EU               77.634700  475.2301  452.5143
# 61          SVN             EU               73.098700  509.9196  505.2159
# 62          SWE             EU               90.610200  493.9181  500.1556
# 66          TUR             EU               53.744979  420.4540  428.3351
#
#      Science
# 0   427.2250
# 4   495.0375
# 5   501.9997
# 6   445.7720
# 9   505.5058
# 14  432.5964
# 15  492.8300
# 16  509.1406
# 17  501.9369
# 20  492.7861
# 21  534.1937
# 22  530.6612
# 23  494.9776
# 24  509.2215
# 26  454.8288
# 28  475.3912
# 29  476.7475
# 31  502.5751
# 32  473.2301
# 34  480.5468
# 40  475.4089
# 41  482.8064
# 42  490.2250
# 44  427.9978
# 46  383.6824
# 47  464.7819
# 48  411.3136
# 50  508.5748
# 51  498.4811
# 54  501.4353
# 55  501.1001
# 57  434.8849
# 58  486.6310
# 60  460.7749
# 61  512.8636
# 62  493.4224
# 66  425.4895

# %%
AF = PISA_Test[PISA_Test['Continent_Code'] == 'AF']
AF
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 19          DZA             AF               38.200000  359.6062  349.8593
# 65          TUN             AF               48.519836  366.8180  361.0555
#
#      Science
# 19  375.7451
# 65  386.4034

# %%
NA = PISA_Test[PISA_Test['Continent_Code'] == "NA"]
NA
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 8           CAN             NA               88.470000  515.6474  526.6678
# 13          CRI             NA               59.762950  400.2534  427.4875
# 18          DOM             NA               54.215766  327.7020  357.7377
# 45          MEX             NA               57.431043  408.0235  423.2765
# 68          USA             NA               74.554202  469.6285  496.9351
#
#      Science
# 8   527.7047
# 13  419.6080
# 18  331.6388
# 45  415.7099
# 68  496.2424

# %%
SA = PISA_Test[PISA_Test['Continent_Code'] == 'SA']
SA
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 2           ARG             SA               68.043064  409.0333  425.3031
# 7           BRA             SA               58.327952  377.0695  407.3486
# 10          CHL             SA               64.289000  422.6714  458.5709
# 12          COL             SA               55.904973  389.6438  424.9052
# 53          PER             SA               40.900000  386.5606  397.5414
# 64          TTO             SA               69.198471  417.2434  427.2733
# 67          URY             SA               64.600000  417.9919  436.5721
#
#      Science
# 2   432.2262
# 7   400.6821
# 10  446.9561
# 12  415.7288
# 53  396.6836
# 64  424.5905
# 67  435.3630

# %%
OC = PISA_Test[PISA_Test['Continent_Code'] == 'OC']
OC
# Out:
#    Country Code Continent_Code  internet_users_per_100      Math   Reading  \
# 3           AUS             OC               84.560519  493.8962  502.9006
# 52          NZL             OC               88.222889  495.2233  509.2707
#
#      Science
# 3   509.9939
# 52  513.3035

# %%
PISA_Test.shape
# Out:
# (70, 6)

# %%
PISA_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country Code            70 non-null     object
#  1   Continent_Code          70 non-null     object
#  2   internet_users_per_100  70 non-null     float64
#  3   Math                    70 non-null     float64
#  4   Reading                 70 non-null     float64
#  5   Science                 70 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 3.4+ KB

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Exploring EU & ASIAN Countries:</p>
#
# Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots. CHECK: statistic=0.870055317967983, pvalue=0.38826888111307345

# %%
PISA_Test.rename(columns={'Country Code':'Country_Code'}, inplace=True)

PISA_Test
# Out:
#    Country_Code Continent_Code  internet_users_per_100      Math   Reading  \
# 0           ALB             EU               63.252933  413.1570  405.2588
# 1           ARE             AS               90.500000  427.4827  433.5423
# 2           ARG             SA               68.043064  409.0333  425.3031
# 3           AUS             OC               84.560519  493.8962  502.9006
# 4           AUT             EU               83.940142  496.7423  484.8656
# ..          ...            ...                     ...       ...       ...
# 65          TUN             AF               48.519836  366.8180  361.0555
# 66          TUR             EU               53.744979  420.4540  428.3351
# 67          URY             SA               64.600000  417.9919  436.5721
# 68          USA             NA               74.554202  469.6285  496.9351
# 69          VNM             AS               43.500000  494.5183  486.7738
#
#      Science
# 0   427.2250
# 1   436.7311
# 2   432.2262
# 3   509.9939
# 4   495.0375
# ..       ...
# 65  386.4034
# 66  425.4895
# 67  435.3630
# 68  496.2424
# 69  524.6445
#
# [70 rows x 6 columns]

# %%
# EU_Math = PISA_Test.loc[PISA_Test['Continent_Code'] == 'EU']['Math']
EU_Math = PISA_Test.loc[PISA_Test['Continent_Code'] == 'EU',['Math']]

EU_Math
# Out:
#         Math
# 0   413.1570
# 4   496.7423
# 5   506.9844
# 6   441.1899
# 9   521.2506
# 14  437.1443
# 15  492.3254
# 16  505.9713
# 17  511.0876
# 20  485.8432
# 21  519.5291
# 22  511.0769
# 23  492.9204
# 24  492.4785
# 26  453.6299
# 28  464.0401
# 29  476.8309
# 31  503.7220
# 32  488.0332
# 34  489.7287
# 40  478.3834
# 41  485.7706
# 42  482.3051
# 44  419.6635
# 46  371.3114
# 47  478.6448
# 48  417.9341
# 50  512.2528
# 51  501.7298
# 54  504.4693
# 55  491.6270
# 57  443.9543
# 58  494.0600
# 60  475.2301
# 61  509.9196
# 62  493.9181
# 66  420.4540

# %%
# AS_Math = PISA_Test.loc[PISA_Test['Continent_Code'] == 'AS']['Math']
AS_Math = PISA_Test.loc[PISA_Test['Continent_Code'] == 'AS',['Math']]
AS_Math
# Out:
#         Math
# 1   427.4827
# 11  531.2961
# 25  403.8332
# 27  547.9310
# 30  386.1096
# 33  469.6695
# 35  380.2590
# 36  532.4399
# 37  459.8160
# 38  524.1062
# 39  396.2497
# 43  543.8078
# 49  446.1098
# 56  402.4007
# 59  564.1897
# 63  415.4638
# 69  494.5183

# %%
EU_Math.describe()
# Out:
#              Math
# count   37.000000
# mean   477.981449
# std     35.150403
# min    371.311400
# 25%    464.040100
# 50%    489.728700
# 75%    503.722000
# max    521.250600

# %%
AS_Math.describe()
# Out:
#              Math
# count   17.000000
# mean   466.216647
# std     64.356490
# min    380.259000
# 25%    403.833200
# 50%    459.816000
# 75%    531.296100
# max    564.189700

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">1. Stating Null (H0) & Alternative (Ha) Hypotheses:</p>

# %% [raw]
# H0 = mu_EU_Math == mu_AS_Math
# Ha = mu_EU_Math != mu_AS_Math

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">2. Calculating Test Statistics:</p>

# %%
indTest = stats.ttest_ind(EU_Math, AS_Math, equal_var=True)
indTest
# Out:
# TtestResult(statistic=array([0.87005532]), pvalue=array([0.38826888]), df=array([52.]))

# %%
test_statistic = indTest.statistic
test_statistic[0]
# Out:
# 0.870055317967983

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">3. Calculaing P-Value:</p>

# %%
p_value = indTest.pvalue
p_value[0]
# Out:
# 0.38826888111307345

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">4. Making a Decision:</p>

# %% [markdown]
# <img src=https://i.ibb.co/NCLKcFs/p-value-reject-area.png width="400" height="200">

# %%
alpha = 0.05

if indTest.pvalue < alpha:
    print("Reject H0. At the α=0.05, we have sufficient evidence to indicate that Math Score of EU differs from that of Asian Countries.")
else:
    print("Fail to reject H0.")
# Out:
# Fail to reject H0.

# %% [markdown]
# #### <p style="background-color:#8CCED1; font-family:newtimeroman; color:#635EA7; font-size:175%; text-align:left; border-radius:10px 10px;">Visualization:</p>

# %%
# PISA_Test.loc[(PISA_Test['Continent_Code'] == 'AS') & (PISA_Test['Continent_Code'] =='EU'),['Math']]

EU_AS_Math = PISA_Test.loc[(PISA_Test['Continent_Code'].isin(['AS','EU'])),['Continent_Code','Math']]

EU_AS_Math
# Out:
#    Continent_Code      Math
# 0              EU  413.1570
# 1              AS  427.4827
# 4              EU  496.7423
# 5              EU  506.9844
# 6              EU  441.1899
# 9              EU  521.2506
# 11             AS  531.2961
# 14             EU  437.1443
# 15             EU  492.3254
# 16             EU  505.9713
# 17             EU  511.0876
# 20             EU  485.8432
# 21             EU  519.5291
# 22             EU  511.0769
# 23             EU  492.9204
# 24             EU  492.4785
# 25             AS  403.8332
# 26             EU  453.6299
# 27             AS  547.9310
# 28             EU  464.0401
# 29             EU  476.8309
# 30             AS  386.1096
# 31             EU  503.7220
# 32             EU  488.0332
# 33             AS  469.6695
# 34             EU  489.7287
# 35             AS  380.2590
# 36             AS  532.4399
# 37             AS  459.8160
# 38             AS  524.1062
# 39             AS  396.2497
# 40             EU  478.3834
# 41             EU  485.7706
# 42             EU  482.3051
# 43             AS  543.8078
# 44             EU  419.6635
# 46             EU  371.3114
# 47             EU  478.6448
# 48             EU  417.9341
# 49             AS  446.1098
# 50             EU  512.2528
# 51             EU  501.7298
# 54             EU  504.4693
# 55             EU  491.6270
# 56             AS  402.4007
# 57             EU  443.9543
# 58             EU  494.0600
# 59             AS  564.1897
# 60             EU  475.2301
# 61             EU  509.9196
# 62             EU  493.9181
# 63             AS  415.4638
# 66             EU  420.4540
# 69             AS  494.5183

# %%
EU_AS_continent_index = EU_AS_Math['Continent_Code'].value_counts().index

EU_AS_continent_index
# Out:
# Index(['EU', 'AS'], dtype='object', name='Continent_Code')

# %%
EU_AS_continent_values = EU_AS_Math['Continent_Code'].value_counts().values

EU_AS_continent_values
# Out:
# array([37, 17])

# %%
plt.figure(figsize=(14,10))

ax = sns.boxplot(data=EU_AS_Math, x='Continent_Code', y='Math', hue='Continent_Code')
plt.ylabel('Math Scores')
plt.xlabel('Continents')

plt.xticks(ticks=EU_AS_continent_index, labels=['EU','Asian'])

plt.title('PISA Math Scores in 2015', fontsize=18)

plt.show();

# %% [markdown]
# ## <p style="background-color:#8CCED1; font-family:newtimeroman; color:#49519E; font-size:150%; text-align:center; border-radius:10px 10px;">END OF THE ASSIGNMENT-02</p>
#
# # Now. it's time to relax!
#
# ![Image_Assignment](https://i.ibb.co/QF5G0yf/reading-books-1110x600.png)
# [Image Credit](https://booksunlimited.ie/how-to-make-time-for-reading-books-in-a-busy-schedule/)
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY_Courses"></p>

# %% [markdown]
# <a href="https://ondiande.com/contact/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="ONDIA Contact" width="110" height="200" title="This notebook is licensed by ONDIA. Please contact the authorized persons about the conditions under which you can use or share."></a>
